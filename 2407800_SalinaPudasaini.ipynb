# %% [markdown]
# **Name: Salina Pudasaini**
#
# **Student Id: 2407800**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **3 Tasks - To - Do:**

# %% [markdown]
# Please Solve all the Problems as instructed:

# %% [markdown]
# **3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:**

# %% [markdown]
# **1. Data Exploration and Understanding:**

# %% [markdown]
# **•** Dataset Overview:

# %% [markdown]
# 1. Load the dataset and display the first 10 rows

# %%
dataset = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
dataset.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
# Check dimensions of the DataFrame
print(f"The DataFrame has {dataset.shape[0]} rows and {dataset.shape[1]} columns.")
# Out:
# The DataFrame has 143 rows and 9 columns.

# %% [markdown]
# 3. List all the columns and their data types

# %%
print("All the columns and their datatype are:\n")
print(dataset.dtypes)
# Out:
# All the columns and their datatype are:
#
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# **•** Basic Statistics:

# %% [markdown]
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
#Mean, Median, and standard deviation value of the ’Score’ column
#Summary statistics
Mean = dataset['score'].mean()
Median = dataset['score'].median()
Standard_Deviation = dataset['score'].std()

print(f"Mean:{Mean}, \nMedian:{Median},\nStandard Deviation:{Standard_Deviation}")
# Out:
# Mean:5.52758041958042,
# Median:5.785,
# Standard Deviation:1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
#calculation of highest and lowest score
#loc property gets the value of the specified labels.
highest_score = dataset.loc[dataset['score'].idxmax()];
lowest_score = dataset.loc[dataset['score'].idxmin()];
print(f"Country with the highest happiness score:{highest_score['Country name']}")
print(f"Country with the lowest happiness score:{lowest_score['Country name']}")
# Out:
# Country with the highest happiness score:Finland
# Country with the lowest happiness score:Afghanistan

# %% [markdown]
# **•** Missing Values:

# %% [markdown]
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
missing_values = dataset.columns[dataset.isnull().any()]
print("Columns with missing values:",missing_values)
missing_values = dataset.isnull().sum()
missing_values_count = missing_values[missing_values > 0]
print("Missing values count for each column:")
print(missing_values_count)
# Out:
# Columns with missing values: Index(['Log GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')
# Missing values count for each column:
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# **•** Filtering and Sorting:

# %% [markdown]
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
score_gt_sevenpointfive = dataset[dataset['score']>7.5]
print("The countries with a Score greater than 7.5 are:\n")
print(score_gt_sevenpointfive)
# Out:
# The countries with a Score greater than 7.5 are:
#
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
sort_by_GDP = score_gt_sevenpointfive.sort_values(by="Log GDP per capita", ascending = False)
print("The sorted dataset by GDP per Capita in descending orderis shown below:")
print(sort_by_GDP.head(10))
# Out:
# The sorted dataset by GDP per Capita in descending orderis shown below:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# **•** Adding New Columns:

# %% [markdown]
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
#
# Medium − (4 ≤ Score ≤ 6)
#
# High − (Score > 6)

# %%
def categorize_happiness(score):
  if(score < 4):
    return "Low"
  elif(4 <= score <= 6):
    return "Medium"
  else:
    return "High"

#apply() method allows to apply a function along one of the axis of the DataFrame, default = row's axis i.e 0
dataset["Happiness Category"] = dataset['score'].apply(categorize_happiness)
print(dataset)
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %% [markdown]
# **2. Data Visualizations:**

# %% [markdown]
# **• Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.**
#
# **• Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.**
#
# **• Plot a histogram for the Score column to show its distribution and also interpret.**
#
# **• Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.**

# %% [markdown]
# **• Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.**

# %%
df = dataset.nlargest(10,'score')
df.plot(kind ="bar",x ="Country name",y ="score" ,title ="Top 10 happiest countries by Score ", color ="green")
# giving X and Y labels
plt.xlabel("Countries")
plt.ylabel("Scores")
plt.show ()

# %% [markdown]
# **Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.**

# %%
df = dataset.nsmallest(10,'score')
df.plot ( x ="Country name", y ="score", kind ="line", title =" Top 10 unhappiest countries by Score", color ="red", marker= "o")
plt.xlabel("Countries")
plt.ylabel("Scores")
plt.show ()

# %% [markdown]
# **• Plot a histogram for the Score column to show its distribution and also interpret.**

# %%
df = dataset['score']
df.plot ( x ="Country name", y ="score", kind ="hist", title =" Score Distribution", color ="skyblue",edgecolor = 'black')
plt.xlabel("Score")
plt.show ()

# %% [markdown]
# **Interpretation:**
#
# As the above histogram for score distribution column has a single peak it is in Unimodial shape. As the tail of the distribution is longer on the left side and peak is on the right side of the center, the skew of score distribution on the histogram is negative(Negatively Skewed).

# %% [markdown]
# **• Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.**

# %%
categories = dataset['Happiness Category'].unique()
colors = {'Low':'red', 'Medium':'blue','High':'green'}
for category in categories:
  category_data = dataset[dataset['Happiness Category'] == category]
  plt.scatter(category_data['Log GDP per capita'],category_data['score'],label = category, color = colors[category])

plt.title('Happiness Score vs. GDP per Capital')
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

# %% [markdown]
# **3.2 Problem - 2 - Some Advance Data Exploration Task:**

# %% [markdown]
# **Task - 1 - Setup Task - Preparing the South-Asia Dataset:**

# %% [markdown]
# 1. Define the countries in South Asia with a list for example:
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Sri Lanka"]
filtered_df = dataset[dataset["Country name"].isin(south_asian_countries)]
#Writing Dataframe to csv.
#index=False argument prevents Pandas from adding an index column to CSV file
filtered_df.to_csv("southasia.csv", index=False)

# %% [markdown]
# **Task - 2 - Composite Score Ranking:**

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score
#  = 0.40 × GDP per Capita + 0.30 × Social Support+ 0.30 × Healthy Life Expectancy

# %%
south_asia_df = pd.read_csv("/content/southasia.csv")
#Create new column
south_asia_df['Composite Score'] = 0.40 * south_asia_df['Log GDP per capita'] + 0.30 * south_asia_df['Social support'] + 0.30 * south_asia_df['Healthy life expectancy']

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
composite_score_rank = south_asia_df.sort_values(by = 'Composite Score', ascending = False)
composite_score_rank.head(6)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score

# %%
top_5_countries = composite_score_rank.head(5)
top_5_countries.plot(kind ="barh",x ='Country name',y ='Composite Score' ,title ='Bar chart of Top 5 countries on the basis of Composite Score', color ="brown")
# giving X and Y labels
plt.xlabel("Composite Score")
plt.ylabel("Countries")
plt.show ()

# %% [markdown]
# **4.Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.**

# %%
scatter=south_asia_df[['Composite Score','score']]
scatter.plot(x='Composite Score',y='score',kind='scatter',title='Scatter plot between  Composite Score and the original Score',color='blue')
plt.xlabel('Composite Score')
plt.ylabel('Original Score')
plt.show()

# %% [markdown]
# **Task - 3 - Outlier Detection:**

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages

# %%
#Calculation for Outliers
#CALCULATION OF Q1, Q3 and IQR FOR SCORE
Q1_score = south_asia_df['score'].quantile(0.25)
Q3_score = south_asia_df['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

#CALCULATION OF Q1, Q3 and IQR FOR GDP per capita
Q1_GDP = south_asia_df['Log GDP per capita'].quantile(0.25)
Q3_GDP = south_asia_df['Log GDP per capita'].quantile(0.75)
IQR_GDP = Q3_GDP - Q1_GDP

#CALCULATION OF LOWER BOUND AND UPPER BOUNDS
lower_bound_score = Q1_score - 1.5 *  IQR_score
upper_bound_score = Q3_score + 1.5*  IQR_score

lower_bound_GDP = Q1_GDP - 1.5 *  IQR_GDP
upper_bound_GDP = Q3_GDP + 1.5 *  IQR_GDP

#IDENTIFICATION OF OUTLIERS
outliers_score = south_asia_df[(south_asia_df['score'] < lower_bound_score) | (south_asia_df['score'] > upper_bound_score)]
outliers_GDP = south_asia_df[(south_asia_df['Log GDP per capita'] < lower_bound_GDP) | (south_asia_df['Log GDP per capita'] > upper_bound_GDP)]

print(outliers_score['Country name'])
print(outliers_GDP['Country name'])
# Out:
# 5    Afghanistan
# Name: Country name, dtype: object
# 5    Afghanistan
# Name: Country name, dtype: object

# %% [markdown]
# Here is the Scatter Plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers in a different color:

# %%
#plotting the normal or reqular points
plt.scatter(south_asia_df['Log GDP per capita'],south_asia_df['score'],color='green',label='Normal')
#plotting the outliers
plt.scatter(outliers_GDP['Log GDP per capita'],outliers_score['score'],color='blue',label='Outliers')
plt.title ('Scatter plot with GDP per Capita and Score')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
# plt.xlim(0,)
# plt.ylim(0,)
plt.legend()
plt.grid()
plt.show ()

# %% [markdown]
# **4. Discuss the characteristics of these outliers and their potential impact on regional averages.**

# %% [markdown]
# **ANS:**
# As we can see in the above scatter plot the blue dot is an outlier with a Log GDP per capita around 0.63 and score below 2.0.It have extremely low data point relative to the rest of the co-existing values.
#
# As the score for outlier  is below 2.0 where the other values are above 3. When we calculate an average, the mean, the outlier will pull the average score in the direction of outlier which may conclude average score is much lesser. So, here outlier is not representing the majority of the data.

# %% [markdown]
# **Task - 4 - Exploring Trends Across Metrics:**

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
#CALCULATION OF CORRELATION
correlationof_score_with_freedom = south_asia_df['Freedom to make life choices'].corr(south_asia_df['score'])
correlationof_score_with_generosity = south_asia_df['Generosity'].corr(south_asia_df['score'])
print("The correlation between Freedom to make life choices and score is :",correlationof_score_with_freedom)
print("\nThe correlation between Generosity and score is :",correlationof_score_with_generosity)
# Out:
# The correlation between Freedom to make life choices and score is : 0.8005185224163315
#
# The correlation between Generosity and score is : 0.874512371253192

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
df1=south_asia_df[['Freedom to make life choices','score']]
df1.plot(kind='scatter',x='Freedom to make life choices',y='score',color='green',label='data point')
# Calculating the bestfit line
z = np.polyfit(df1['Freedom to make life choices'], df1['score'], 1)
p = np.poly1d(z)
plt. plot(df1['Freedom to make life choices'], p(df1['Freedom to make life choices']), 'blue',label='trendline')
plt.title("Scatter plot of Freedom to make life choices against score")
plt.legend()

df2=south_asia_df[['Generosity','score']]
df2.plot(kind='scatter',x='Generosity',y='score',color='blue',label='data point')
z1 = np.polyfit(df2['Generosity'], df2['score'], 1)
p1 = np.poly1d(z1)
plt. plot(df2['Generosity'], p1(df2['Generosity']), color="red",label='trendline')
plt.title("Scatter plot of Generosity against score")
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')
plt.legend()
plt.show ()

# %% [markdown]
# **3.Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.**

# %% [markdown]
# **Ans:**
# The correlation coefficient gives the relationship between the Freedom to Make Life Choices and Generosity against score. Here the correlation between Freedom to make life choices and score is  0.8005 wheres as the correlation between Generosity and score is : 0.8745. Both have relatively strong relation but as the correlation between Generosity and score is  0.8745 which is more closer to 1 there exist a strongest relation  between these Generosity and the Score for South Asian countries.

# %% [markdown]
# **Task - 5 - Gap Analysis:**

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']
print(south_asia_df)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
rank_gap_ascending = south_asia_df.sort_values(by = 'GDP-Score Gap')
rank_gap_descending = south_asia_df.sort_values(by = 'GDP-Score Gap', ascending = False)
print('South Asian countries by GDP-Score Gap in ascending order:\n',rank_gap_ascending['Country name'])
print('South Asian countries by GDP-Score Gap in descending order:\n',rank_gap_descending['Country name'])
# Out:
# South Asian countries by GDP-Score Gap in ascending order:
#  0          Nepal
# 1       Pakistan
# 2          India
# 4     Bangladesh
# 3      Sri Lanka
# 5    Afghanistan
# Name: Country name, dtype: object
# South Asian countries by GDP-Score Gap in descending order:
#  5    Afghanistan
# 3      Sri Lanka
# 4     Bangladesh
# 2          India
# 1       Pakistan
# 0          Nepal
# Name: Country name, dtype: object

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
largest_positive = south_asia_df.nlargest(3,'GDP-Score Gap')
largest_negative = south_asia_df.nsmallest(3,'GDP-Score Gap')
# plotting the largest and positive gaps using bar chart
combined_largestPositiveandNegative = pd.concat([largest_positive,largest_negative]).sort_values(by='GDP-Score Gap')
plt.barh(combined_largestPositiveandNegative['Country name'],combined_largestPositiveandNegative['GDP-Score Gap'],color=['#aceb75'if gap < 3 else '#f34222' for gap in range(0,6)])
plt.title('Bar chart showing Top 3 Countries with largest and smallest negative gaps')

plt.xlabel("GDP-Score Gap")
plt.ylabel("Countries")

plt.show()

# %% [markdown]
# **3.3 Problem - 3 - Comparative Analysis:**

# %% [markdown]
# **Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:**

# %% [markdown]
# **Tasks:**

# %% [markdown]
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]
# Complete the following task:

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "State of Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
filtered_df = dataset[dataset["Country name"].isin(middle_east_countries)]

#Writing Dataframe to csv.
#index=False argument prevents Pandas from adding an index column to CSV file
filtered_df.to_csv("middle_east.csv", index=False)

# %%
middle_east_df = pd.read_csv("/content/middle_east.csv")

# %% [markdown]
# Complete the following task:

# %% [markdown]
# **1. Descriptive Statistics:**
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.

# %%
#CALCULATION OF MEAN AND STANDARD DEVIATION OF SCORE FOR SOUTH ASIA
Mean_south_asia = south_asia_df['score'].mean()
Standard_Deviation_south_asia  = south_asia_df['score'].std()

#CALCULATION OF MEAN AND STANDARD DEVIATION OF SCORE FOR MIDDLE EAST
Mean_middle_east = middle_east_df['score'].mean()
Standard_Deviation_middle_east = middle_east_df['score'].std()

print(f"Mean of the score of South Asia :{Mean_south_asia}, \nStandard Deviation of the score of South Asia :{Standard_Deviation_south_asia}")
print(f"Mean of the score of Middle East :{Mean_middle_east}, \nStandard Deviation of the score of South Asia :{Standard_Deviation_middle_east}")
# Out:
# Mean of the score of South Asia :3.895666666666667,
# Standard Deviation of the score of South Asia :1.1770690152521504
# Mean of the score of Middle East :5.363636363636363,
# Standard Deviation of the score of South Asia :1.4944977265106343

# %% [markdown]
# • Which region has higher happiness Scores on average?

# %% [markdown]
# **ANS:**
# As the average happiness score of Middle East is 5.4121 indicating the high level of happiness in comaprison to average happiness score of South Asia which is 3.8952. So, Middle East region has higher happiness Scores on average.

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
top_performers_south_asia = south_asia_df.nlargest(3,'score')
bottom_performers_south_asia = south_asia_df.nsmallest(3,'score')

top_performers_middle_east = middle_east_df.nlargest(3,'score')
bottom_performers_middle_east = middle_east_df.nsmallest(3,'score')

print("Top 3 countries in South Asia region based on the score\n",top_performers_south_asia['Country name'])
print("\nBottom 3 countries in South Asia region based on the score\n",bottom_performers_south_asia['Country name'])

print("\nTop 3 countries in Middle East region based on the score\n",top_performers_middle_east['Country name'])
print("\nBottom 3 countries in Middle East region based on the score\n",bottom_performers_middle_east['Country name'])
# Out:
# Top 3 countries in South Asia region based on the score
#  0       Nepal
# 1    Pakistan
# 2       India
# Name: Country name, dtype: object
#
# Bottom 3 countries in South Asia region based on the score
#  5    Afghanistan
# 4     Bangladesh
# 3      Sri Lanka
# Name: Country name, dtype: object
#
# Top 3 countries in Middle East region based on the score
#  0                  Israel
# 1                  Kuwait
# 2    United Arab Emirates
# Name: Country name, dtype: object
#
# Bottom 3 countries in Middle East region based on the score
#  10    Lebanon
# 9       Yemen
# 8      Jordan
# Name: Country name, dtype: object

# %% [markdown]
# • Plot bar charts comparing these charts.

# %%
top_performers_south_asia.plot(kind ="bar",x ='Country name',y ='score' ,title ='Top 3  South Asian countries based on the score', color ="#2ed486")
plt.xlabel("Countries")
plt.ylabel("Score")
bottom_performers_south_asia.plot(kind ="bar",x ='Country name',y ='score' ,title ='Bottom 3 South Asian countries based on the score', color ="#f5505a")
plt.xlabel("Countries")
plt.ylabel("Score")

top_performers_middle_east.plot(kind ="bar",x ='Country name',y ='score' ,title ='Top 3  Middle East countries based on the score', color ="#2ed486")
plt.xlabel("Countries")
plt.ylabel("Score")
bottom_performers_middle_east.plot(kind ="bar",x ='Country name',y ='score' ,title ='Bottom 3 Middle Eaast countries based on the score', color ="#f5505a")
plt.xlabel("Countries")
plt.ylabel("Score")

# giving X and Y labels
plt.legend()
plt.show ()

# %% [markdown]
# 3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.

# %%
# Metrics to compare
metrics = ['Log GDP per capita','Social support','Healthy life expectancy']

#calculation of mean
metric_mean_for_SA = south_asia_df[metrics].mean()
metric_mean_for_ME = middle_east_df[metrics].mean()
# X-axis positions
x = np.arange(len(metrics))
plt.figure(figsize = (12,6))
# Bar width
width = 0.25
# for Databars space 0.15
plt.bar(x - 0.15, metric_mean_for_SA, width, label ='South Asia')
plt.bar(x + 0.15, metric_mean_for_ME, width, label ='Middle East')
plt.title('Grouped bar charts showing comparison of Key Metrics between South Asia and Middle East')
plt.xlabel('Metrics')
plt.ylabel('Values')
# Set x-axis tick positions and labels
plt.xticks(ticks=x, labels=metrics)
plt.legend()
plt.show()

# %% [markdown]
# • Which metrics show the largest disparity between the two regions?

# %% [markdown]
# **ANS:**
# In the above Grouped bar chart the Social support metrics shows the largest disparity between two region as the Social support mertics of South Asia ranges around 0.6 which is like half of the Middle East(i.e. 1.2).

# %% [markdown]
# **4.Happiness Disparity:**

# %% [markdown]
# **•** Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# **•** Which region has greater variability in happiness?

# %%
max_Of_Asia = south_asia_df['score'].max()
min_Of_Asia = south_asia_df['score'].min()
rangeOfasia = max_Of_Asia - min_Of_Asia

max_Of_Middleeast = middle_east_df['score'].max()
min_Of_Middleeast = middle_east_df['score'].min()
rangeOfmiidleeast = max_Of_Middleeast - min_Of_Middleeast

cvOfsouthasia = Standard_Deviation_south_asia/Mean_south_asia
cvofmiddleEast = Standard_Deviation_middle_east/Mean_middle_east

print("Range for Score in South Asia:",rangeOfasia)
print("Range for Score in Middle East:",rangeOfmiidleeast)
print("CV for Score in South Asia:",cvOfsouthasia)
print("CV for Score in Middle East:",cvofmiddleEast)
# Out:
# Range for Score in South Asia: 3.4370000000000003
# Range for Score in Middle East: 4.634
# CV for Score in South Asia: 0.3021482883337427
# CV for Score in Middle East: 0.2786351693494403

# %% [markdown]
# • Which region has greater variability in happiness?

# %% [markdown]
# **ANS:**
# As the coeffiecient of variation for Score in South Asia is 0.30 which is larger in comparison to coeffiecient of variation for Score in Middle East which is 0.28. So, South Asia indicates greater variability in happiness.

# %% [markdown]
# **5. Correlation Analysis:**

# %% [markdown]
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
#CALCULATION OF CORRELATION
#WITHIN MIDDLE EAST REGION
correlationof_score_with_freedom_of_middle_east = middle_east_df['Freedom to make life choices'].corr(middle_east_df['score'])
correlationof_score_with_generosity_of_middle_east = middle_east_df['Generosity'].corr(middle_east_df['score'])

print("The correlation between Freedom to make life choices and score within south asian region is :",correlationof_score_with_freedom)
print("\nThe correlation between Generosity and score within south asian region is :",correlationof_score_with_generosity)
print("\nThe correlation between Freedom to make life choices and score within middle east region is :",correlationof_score_with_freedom_of_middle_east)
print("\nThe correlation between Generosity and score within middle east region is :",correlationof_score_with_generosity_of_middle_east)
# Out:
# The correlation between Freedom to make life choices and score within south asian region is : 0.8005185224163315
#
# The correlation between Generosity and score within south asian region is : 0.874512371253192
#
# The correlation between Freedom to make life choices and score within middle east region is : 0.8632202433827543
#
# The correlation between Generosity and score within middle east region is : 0.6275236536964182

# %% [markdown]
# • Create scatter plots to visualize and interpret the relationships.

# %%
#FOR SOUTH ASIA REGION between Freedom to make life choices and score
plt.figure(figsize=(8,5))
plt.scatter(south_asia_df['Freedom to make life choices'], south_asia_df[ 'score'],label='Datapoint')
x=south_asia_df['Freedom to make life choices']
y=south_asia_df['score']
slope=np.cov(x,y) [0,1]/np.var(x)
intercept = y.mean()-slope*x.mean()
plt.plot(x,slope*x+intercept, color='red',label='Trendline')
plt.xlabel("Freeom to make life choices")
plt.title("Freedom of life choices vs score(South Asia)")
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

#FOR SOUTH ASIA REGION for Generosity against score
plt.figure(figsize=(8,5))
plt.scatter(south_asia_df['Generosity'], south_asia_df[ 'score'],label='Datapoint')
x=south_asia_df['Generosity']
y=south_asia_df['score']
slope=np.cov(x,y) [0,1]/np.var(x)
intercept = y.mean()-slope*x.mean()
plt.plot(x,slope*x+intercept, color='red',label='Trendline')
plt.xlabel("Genorisity")
plt.title("Generosity vs score(South Asia)")
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

#FOR MIDDLE EASTREGION between Freedom to make life choices and score
plt.figure(figsize=(8,5))
plt.scatter(middle_east_df['Freedom to make life choices'], middle_east_df['score'],label='Datapoint')
x1=middle_east_df['Freedom to make life choices']
y1=middle_east_df['score']
slope = np.cov(x1,y1)[0,1] / np.var(x1)
intercept = y1.mean()-slope*x1.mean()
plt.plot(x1, (slope*x1+intercept) ,color='skyblue',label='Trendline')
plt.xlabel("Freeom to make life choices")
plt.title("Freedom of life choices vs score(Middle East)")
plt.ylabel('Happiness Score')
plt.legend()
plt.show()
#FOR MIDDLE EAST REGION for Generosity against score
plt.figure(figsize=(8,5))
plt.scatter(middle_east_df['Generosity'],middle_east_df[ 'score'],label='Datapoint')
x1=middle_east_df['Generosity']
y1=middle_east_df['score']
slope=np.cov(x1,y1) [0,1]/np.var(x1)
intercept = y1.mean()-slope*x1.mean()
plt.plot(x1,slope*x1+intercept, color='green',label='Trendline')
plt.xlabel("Genorisity")
plt.title("Generosity vs score(Middle East)")
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

# %% [markdown]
# **6. Outlier Detection:**

# %% [markdown]
# **•** Identify outlier countries in both regions based on Score and GDP per Capita.
#
# **•**Plot these outliers and discuss their implications.

# %%
#Calculation for Outliers
#CALCULATION OF Q1, Q3 and IQR FOR SCORE
Q1_score = middle_east_df['score'].quantile(0.25)
Q3_score = middle_east_df['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

#CALCULATION OF Q1, Q3 and IQR FOR GDP per capita
Q1_GDP = middle_east_df['Log GDP per capita'].quantile(0.25)
Q3_GDP = middle_east_df['Log GDP per capita'].quantile(0.75)
IQR_GDP = Q3_GDP - Q1_GDP

#CALCULATION OF LOWER BOUND AND UPPER BOUNDS
lower_bound_score = Q1_score - 1.5 *  IQR_score
upper_bound_score = Q3_score + 1.5*  IQR_score

lower_bound_GDP = Q1_GDP - 1.5 *  IQR_GDP
upper_bound_GDP = Q3_GDP + 1.5 *  IQR_GDP

#IDENTIFICATION OF OUTLIERS
outliers_score_MiddleEast = middle_east_df[(middle_east_df['score'] < lower_bound_score) | (middle_east_df['score'] > upper_bound_score)]
outliers_GDP_MiddleEast= middle_east_df[(middle_east_df['Log GDP per capita'] < lower_bound_GDP) | (middle_east_df['Log GDP per capita'] > upper_bound_GDP)]

print(outliers_score['Country name'])
print(outliers_GDP['Country name'])

print(outliers_score_MiddleEast['Country name'])
print(outliers_GDP_MiddleEast['Country name'])
# Out:
# 5    Afghanistan
# Name: Country name, dtype: object
# 5    Afghanistan
# Name: Country name, dtype: object
# Series([], Name: Country name, dtype: object)
# Series([], Name: Country name, dtype: object)

# %% [markdown]
# •Plot these outliers and discuss their implications.

# %%
#plotting the normal or reqular points
plt.scatter(south_asia_df['Log GDP per capita'],south_asia_df['score'],color='green',label='Normal')
#plotting the outliers
plt.scatter(outliers_GDP['Log GDP per capita'],outliers_score['score'],color='blue',label='Outliers')
plt.title ('fig:1:Scatter plot with GDP per Capita and Score in South Asia region')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()
plt.show ()
#plotting the normal or reqular points
plt.scatter(middle_east_df['Log GDP per capita'],middle_east_df['score'],color='green',label='Normal')
#plotting the outliers
plt.scatter(outliers_GDP_MiddleEast['Log GDP per capita'],outliers_score_MiddleEast['score'],color='blue',label='Outliers')
plt.title ('fig:2:Scatter plot with GDP per Capita and Score in Middle East regions')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()
plt.show ()

# %% [markdown]
# **Implications**

# %% [markdown]
# **ANS:**
#
# *FIG:1:*
#
# On the first figure showing Scatter plot with GDP per Capita and Score in South Asia region Afghanistan is the outlier country as it have extremely low data point relative to the rest of the co-existing values. The scatter plot ina blue dot stand out far from the overall pattern of values in the above graph.
#
# *FIG:2:*
# On the second figure showing Scatter plot with GDP per Capita and Score in Middle East region there is not any outlier country as there is no such data point which is far away from the co-existing data or rest of the data.

# %% [markdown]
# **7. Visualization:**

# %% [markdown]
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East

# %%
#Creating boxplot
plt.figure(figsize=(8, 5))

plt.boxplot([south_asia_df['score'],middle_east_df['score']], labels = ['South Asia','Middle East'])
plt.title('Comparison of Score Distribution between South Asia and Middle East')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# **• Interpret the key differences in distribution shapes, medians, and outliers.**

# %% [markdown]
# The above box plots shows the distribution of score between South asia and Middle East.
#
# In the above boxplot, The horizontal lines at the front and back of the box are whiskers,the upper whisker represents the maximum score and the lower represents minimum score. There is no whisker for minimun score in South Asia. The horizontal line within the box indicates the median. Both the inter quartile range lies on lower quartile or Q1. There is one outlier in the South Asia.
